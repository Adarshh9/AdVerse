# %%
pip install moviepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.version
# Out:
# '3.11.7 (main, Dec  8 2023, 18:56:58) [GCC 11.4.0]'

# %%
# !pip show moviepy
# Out:
# Name: moviepy
# Version: 1.0.3
# Summary: Video editing with Python
# Home-page: https://zulko.github.io/moviepy/
# Author: Zulko 2017
# Author-email:
# License: MIT License
# Location: /home/adarsh/.local/lib/python3.10/site-packages
# Requires: decorator, imageio, imageio-ffmpeg, numpy, numpy, proglog, requests, tqdm
# Required-by:

# %%
from moviepy.config import change_settings

# Specify the path to the ImageMagick binary
change_settings({"IMAGEMAGICK_BINARY": "/usr/bin/convert"})

# %%
from moviepy.editor import VideoFileClip, TextClip, CompositeVideoClip
import numpy as np

# %%
# Function to create a sparkling effect
def sparkling_effect(t, freq=2, ampl=2):
    return [ampl * np.sin(freq * 2 * np.pi * t), ampl * np.sin(freq * 2 * np.pi * t)]

# Load the video clip
video_clip = VideoFileClip("000000.mp4")

# Create a TextClip with the sparkling effect
sparkling_clip = TextClip(".", fontsize=100, color="white", bg_color="transparent")
sparkling_clip = sparkling_clip.set_duration(video_clip.duration)
sparkling_clip = sparkling_clip.set_position(('center', 'center'))
sparkling_clip = sparkling_clip.set_mask(sparkling_clip.mask.fx(sparkling_effect))

# Combine the original video and the sparkling effect
final_clip = CompositeVideoClip([video_clip, sparkling_clip])

# Write the result to a file
final_clip.write_videofile("output_video.mp4", codec="libx264", audio_codec="aac", temp_audiofile="temp-audio.m4a", remove_temp=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/moviepy/video/VideoClip.py:1137, in TextClip.__init__(self, txt, filename, size, color, bg_color, fontsize, font, stroke_color, stroke_width, method, kerning, align, interline, tempfilename, temptxt, transparent, remove_temp, print_cmd)
#    1136 try:
# -> 1137     subprocess_call(cmd, logger=None)
#    1138 except (IOError, OSError) as err:
#
# File ~/.local/lib/python3.11/site-packages/moviepy/tools.py:46, in subprocess_call(cmd, logger, errorprint)
#      44     popen_params["creationflags"] = 0x08000000
# ---> 46 proc = sp.Popen(cmd, **popen_params)
#      48 out, err = proc.communicate() # proc.wait()
#
# ...

# %%
import cv2
import numpy as np

# Function to create a sparkling effect
def sparkling_effect(frame, freq=2, ampl=2):
    t = cv2.getTickCount() / cv2.getTickFrequency()
    alpha = ampl * np.sin(freq * 2 * np.pi * t)
    
    # Apply sparkling effect to the frame
    return cv2.addWeighted(frame, 1 + alpha, np.zeros_like(frame), 0, 0)

# Open video file
video_capture = cv2.VideoCapture("video_of_image.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_opencv.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply sparkling effect to the frame
    frame_sparkling = sparkling_effect(frame)
    
    # Write the frame to the output video
    video_writer.write(frame_sparkling)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
pwd
# Out:
# '/home/adarsh/AdVerse/video_effects'

# %%
import cv2
import numpy as np

# Function to create a fade-in effect
def fade_in_effect(frame, fade_factor=0.02):
    alpha = min(1.0, fade_factor * frame_count)
    
    # Apply fade-in effect to the frame
    return cv2.addWeighted(frame, alpha, np.zeros_like(frame), 0, 0)

# Open video file
video_capture = cv2.VideoCapture("video_of_image.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))
frame_count = 0

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_of_image_fade_in.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply fade-in effect to the frame
    frame_fade_in = fade_in_effect(frame)
    
    # Increment frame count
    frame_count += 1
    
    # Write the frame to the output video
    video_writer.write(frame_fade_in)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("video_of_image.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_grayscale.mp4", fourcc, fps, (width, height), isColor=False)

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply grayscale effect to the frame
    frame_grayscale = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Write the frame to the output video
    video_writer.write(frame_grayscale)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_blur.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply blur effect to the frame
    frame_blur = cv2.GaussianBlur(frame, (15, 15), 0)
    
    # Write the frame to the output video
    video_writer.write(frame_blur)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_edges.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply edge detection effect to the frame
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame_edges = cv2.Canny(frame_gray, 50, 150)
    
    # Convert edges to BGR format
    frame_edges_bgr = cv2.cvtColor(frame_edges, cv2.COLOR_GRAY2BGR)
    
    # Write the frame to the output video
    video_writer.write(frame_edges_bgr)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_inverted_colors.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply invert colors effect to the frame
    frame_inverted = cv2.bitwise_not(frame)
    
    # Write the frame to the output video
    video_writer.write(frame_inverted)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_rotated.mp4", fourcc, fps, (height, width))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply rotate effect to the frame
    frame_rotated = cv2.transpose(frame)
    frame_rotated = cv2.flip(frame_rotated, 1)
    
    # Write the frame to the output video
    video_writer.write(frame_rotated)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
cd video_effects
# Out:
# /home/adarsh/AdVerse/video_effects

# %%
import cv2
import numpy as np

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_sepia.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply sepia tone effect to the frame
    frame_sepia = cv2.transform(frame, np.array([[0.393, 0.769, 0.189],
                                                 [0.349, 0.686, 0.168],
                                                 [0.272, 0.534, 0.131]]))
    frame_sepia = np.clip(frame_sepia, 0, 255).astype(np.uint8)
    
    # Write the frame to the output video
    video_writer.write(frame_sepia)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_vintage.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply vintage film effect to the frame
    frame_vintage = cv2.applyColorMap(frame, cv2.COLORMAP_VIRIDIS)
    
    # Write the frame to the output video
    video_writer.write(frame_vintage)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_painterly.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply painterly effect using bilateral filter
    frame_painterly = cv2.bilateralFilter(frame, d=9, sigmaColor=75, sigmaSpace=75)
    
    # Write the frame to the output video
    video_writer.write(frame_painterly)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_comic_book.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply comic book effect to the frame
    frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    _, frame_threshold = cv2.threshold(frame_gray, 128, 255, cv2.THRESH_BINARY)
    frame_comic_book = cv2.cvtColor(frame_threshold, cv2.COLOR_GRAY2BGR)
    
    # Write the frame to the output video
    video_writer.write(frame_comic_book)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2
import numpy as np

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_dreamy_glow.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break
    
    # Apply dreamy glow effect to the frame
    kernel = np.ones((5, 5), np.float32) / 25
    frame_blur = cv2.filter2D(frame, -1, kernel)
    frame_dreamy_glow = cv2.addWeighted(frame, 1.5, frame_blur, -0.5, 0)
    
    # Write the frame to the output video
    video_writer.write(frame_dreamy_glow)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2
import numpy as np

def add_snowflakes(frame, num_snowflakes=50):
    height, width, _ = frame.shape

    # Create a black image (mask) with the same size as the frame
    mask = np.zeros((height, width), dtype=np.uint8)

    # Generate random positions for snowflakes
    snowflake_positions = np.random.randint(0, width, size=(num_snowflakes, 2))

    # Draw white circles (snowflakes) on the mask
    for position in snowflake_positions:
        cv2.circle(mask, tuple(position), 2, (255), -1)

    # Convert the mask to a binary mask
    _, mask = cv2.threshold(mask, 1, 255, cv2.THRESH_BINARY)

    # Add the snowflakes to the frame
    frame_with_snowflakes = cv2.bitwise_and(frame, frame, mask=mask)

    return frame_with_snowflakes

# Open video file
video_capture = cv2.VideoCapture("000000.mp4")

# Get video properties
fps = video_capture.get(cv2.CAP_PROP_FPS)
width = int(video_capture.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(video_capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

# Create video writer
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
video_writer = cv2.VideoWriter("output_video_snow.mp4", fourcc, fps, (width, height))

while True:
    ret, frame = video_capture.read()
    if not ret:
        break

    # Add snowflakes to each frame
    frame_with_snowflakes = add_snowflakes(frame)

    # Write the frame to the output video
    video_writer.write(frame_with_snowflakes)

# Release video writer and capture
video_writer.release()
video_capture.release()

# %%
import cv2

def merge_videos(video_path1, video_path2, output_path):
    # Open the first video file
    video_capture1 = cv2.VideoCapture(video_path1)
    
    # Get video properties
    fps = video_capture1.get(cv2.CAP_PROP_FPS)
    width = int(video_capture1.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(video_capture1.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Create video writer
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    video_writer = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    # Read and write frames from the first video
    while True:
        ret, frame = video_capture1.read()
        if not ret:
            break
        video_writer.write(frame)

    # Release the first video capture
    video_capture1.release()

    # Open the second video file
    video_capture2 = cv2.VideoCapture(video_path2)

    # Read and write frames from the second video
    while True:
        ret, frame = video_capture2.read()
        if not ret:
            break
        video_writer.write(frame)

    # Release the second video capture and video writer
    video_capture2.release()
    video_writer.release()

# Specify the file paths
video_path1 = "000000.mp4"
video_path2 = "output_video_snow.mp4"
output_path = "merged_video.mp4"

# Merge the two videos
merge_videos(video_path1, video_path2, output_path)

# %%
# Single image to video
import cv2
import numpy as np

# Function to generate a video from a single image
def image_to_video(image_path, output_path, duration=5, frame_rate=24):
    # Load the image
    img = cv2.imread(image_path)

    # Get image dimensions
    height, width, _ = img.shape

    # Create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    video_writer = cv2.VideoWriter(output_path, fourcc, frame_rate, (width, height))

    # Repeat the image to create frames for the specified duration
    for _ in range(int(duration * frame_rate)):
        video_writer.write(img)

    # Release the VideoWriter object
    video_writer.release()

# %%
# Specify the file paths
image_path = "image.png"
output_path = "video_of image.mp4"

# Generate the video from the image
image_to_video(image_path, output_path)

# %% [markdown]
# Final function to convert image into video with effect

# %%
import cv2
import numpy as np

def fade_in_effect(frame, frame_count, fade_factor=0.02):
    alpha = min(1.0, fade_factor * frame_count)
    
    # Apply fade-in effect to the frame
    return cv2.addWeighted(frame, alpha, np.zeros_like(frame), 0, 0)

def image_to_video_with_fade_in(image_path, output_path, duration=5, frame_rate=24, fade_factor=0.02):
    # Load the image
    img = cv2.imread(image_path)

    # Get image dimensions
    height, width, _ = img.shape

    # Create a VideoWriter object
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    video_writer = cv2.VideoWriter(output_path, fourcc, frame_rate, (width, height))

    # Repeat the image to create frames for the specified duration
    for frame_count in range(int(duration * frame_rate)):
        frame_fade_in = fade_in_effect(img, frame_count, fade_factor)
        video_writer.write(frame_fade_in)

    # Release the VideoWriter object
    video_writer.release()

# Example usage
image_path = "image.png"
output_path = "output_video_with_fade_in1.mp4"
image_to_video_with_fade_in(image_path, output_path)
